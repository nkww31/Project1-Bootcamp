# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
import requests

def get_data(page_number):
    base_url = "https://api.example.com/data"  
    params = {
        "page": page_number,
        "per_page": 50  
    }

    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()  
        data = response.json()  
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
import requests

def get_data(page_number):
    base_url = "https://api.example.com/data"  
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }
    params = {
        "page": page_number,
        "per_page": 50  
    }

    try:
        response = requests.get(base_url, headers=headers, params=params)
        response.raise_for_status()  
        data = response.json()  
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
import requests

def fetch_and_extract_content(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  
        content_type = response.headers.get('Content-Type')
        
        if 'application/json' in content_type:
            content = response.json()
        elif 'text/html' in content_type:
            content = response.text  
        else:
            content = response.content 
        
        return content

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
import requests
from bs4 import BeautifulSoup

def scrape_page(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() 
        soup = BeautifulSoup(response.text, 'html.parser')
        
        return soup

    except requests.exceptions.RequestException as e:
        print(f"Error fetching page: {e}")
        return None

# %%
import requests

def fetch_and_extract_content(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() 
        content_type = response.headers.get('Content-Type')
        
        if 'application/json' in content_type:
            content = response.json()
        elif 'text/html' in content_type:
            content = response.text 
        else:
            content = response.content  
        return content

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# %%
import requests
from bs4 import BeautifulSoup

def scrape_page(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        return soup

    except requests.exceptions.RequestException as e:
        print(f"Error fetching page: {e}")
        return None

url = "https://example.com"  
soup = scrape_page(url)

if soup:
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Example Domain
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <style type="text/css">
#    body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#   </style>
#  </head>
# ...

# %%
if soup:
    links = soup.find_all('a')
    for link in links:
        print(link.get('href'))
# Out:
# https://www.iana.org/domains/example

# %%
import requests
from bs4 import BeautifulSoup

def scrape_books(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() 
        soup = BeautifulSoup(response.text, 'html.parser')
        books = soup.find_all('div', class_='book-item') 
        book_data = []
        for book in books:
            book_name = book.find('h2', class_='book-title').text.strip()
            author = book.find('span', class_='author').text.strip()
            rating = book.find('span', class_='rating').text.strip()
            customers_rated = book.find('span', class_='customers-rated').text.strip()
            price = book.find('span', class_='price').text.strip()
            
            book_data.append({
                'Book Name': book_name,
                'Author': author,
                'Rating': rating,
                'Customers Rated': customers_rated,
                'Price': price
            })
        
        return book_data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching page: {e}")
        return None

# %%
no_pages = 2

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_'+str(pageNo)+'?ie=UTF8&pg='+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    

    alls = []
    for d in soup.findAll('div', attrs={'class': 'zg-grid-general-faceout'}):
        name_tag = d.find('div', attrs={'class': '_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y'})
        author_tag = d.find('a', attrs={'class': 'a-size-small a-link-child'})
        rating_tag = d.find('span', attrs={'class': 'a-icon-alt'})
        users_rated_tag = d.find('a', attrs={'class': 'a-link-normal'})
        price_tag = d.find('span', attrs={'class': '_cDEzb_p13n-sc-price_3mJ9Z'})

        name = name_tag.text if name_tag else "unknown-product"
        author = author_tag.text if author_tag else "unknown-author"
        rating = rating_tag.text if rating_tag else "-1"
        
        if users_rated_tag:
            users_rated_span = users_rated_tag.find('span', attrs={'class': 'a-size-small'})
            users_rated = users_rated_span.text if users_rated_span else "0"
        else:
            users_rated = "0"

        price = price_tag.text if price_tag else "0"

        all1 = [name, author, rating, users_rated, price]
        alls.append(all1)

    return alls

# %%
results = []
for i in range(1, no_pages + 1):
    results.extend(get_data(i))

df = pd.DataFrame(results, columns=['Book Name', 'Author', 'Rating', 'Customers_Rated', 'Price'])
df.to_csv('amazon_products.csv', index=False, encoding='utf-8')

# %%
df
# Out:
#                                             Book Name  \
# 0   I Don't Love You Anymore: Moving On and Living...
# 1   My First Library: Boxset of 10 Board Books for...
# 2                          Amma Diarylo Konni Pageelu
# 3                                       Atomic Habits
# 4                             The Psychology of Money
# 5      Ikigai: Japanese secret to long and happy life
# 6                            Dr. Manish Raj (MR. Sir)
# 7   Educart NEET 37 Years Physics, Chemistry and B...
# 8   Pocket Rocket English Formula Book By Prashant...
# 9   The Power of Your Subconscious Mind: Original ...
# 10  My First Book of Patterns Pencil Control: Patt...
# 11  Dopamine Detox : A Short Guide to Remove Distr...
# 12  Animals Tales From Panchtantra: Timeless Stori...
# 13  Coloring Books Box Set: Pack of 12 Copy Color ...
# 14            Shrimad Bhagwat Geeta Yatharoop (Hindi)
# 15  The Mountain Is You: Transforming Self-Sabotag...
# ...

# %%
pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install mysql-connector-python
# Out:
# ...
#   Using cached mysql_connector_python-9.0.0-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB 131.3 kB/s eta 0:01:50
#    ---------------------------------------- 0.0/14.3 MB 131.3 kB/s eta 0:01:50
#    ---------------------------------------- 0.0/14.3 MB 145.2 kB/s eta 0:01:39
#    ---------------------------------------- 0.0/14.3 MB 140.3 kB/s eta 0:01:42
#    ---------------------------------------- 0.1/14.3 MB 269.5 kB/s eta 0:00:53
#    ---------------------------------------- 0.1/14.3 MB 269.5 kB/s eta 0:00:53
#    ---------------------------------------- 0.1/14.3 MB 269.5 kB/s eta 0:00:53
#     --------------------------------------- 0.2/14.3 MB 576.2 kB/s eta 0:00:25
#     --------------------------------------- 0.3/14.3 MB 631.2 kB/s eta 0:00:23
# ...

# %%
from sqlalchemy import create_engine

# %%
db_url = db_url.format(
    USER = "root",
    PWD = "<Hoseok018#BTS",
    HOST = "localhost:3306",
    DBNAME = "test_db"
)

# %%
engine = create_engine(db_url, echo=False)

# %%
with engine.begin() as conn:
    df.to_sql(
        name='amazon_products',
        con=conn,
        index=False,
    )

# %%
pip install Flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from flask import Flask, render_template

# %%
app = Flask(__name__)

# %%
@app.route('/')
def list_items():
    items = [
        {'name': 'Item 1', 'price': '$10'},
        {'name': 'Item 2', 'price': '$20'},
        {'name': 'Item 3', 'price': '$30'},
    ]
    return render_template('items.html', items=items)

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///example.db')

# %%
df
# Out:
#                                             Book Name  \
# 0   I Don't Love You Anymore: Moving On and Living...
# 1   My First Library: Boxset of 10 Board Books for...
# 2                          Amma Diarylo Konni Pageelu
# 3                                       Atomic Habits
# 4                             The Psychology of Money
# 5      Ikigai: Japanese secret to long and happy life
# 6                            Dr. Manish Raj (MR. Sir)
# 7   Educart NEET 37 Years Physics, Chemistry and B...
# 8   Pocket Rocket English Formula Book By Prashant...
# 9   The Power of Your Subconscious Mind: Original ...
# 10  My First Book of Patterns Pencil Control: Patt...
# 11  Dopamine Detox : A Short Guide to Remove Distr...
# 12  Animals Tales From Panchtantra: Timeless Stori...
# 13  Coloring Books Box Set: Pack of 12 Copy Color ...
# 14            Shrimad Bhagwat Geeta Yatharoop (Hindi)
# 15  The Mountain Is You: Transforming Self-Sabotag...
# ...

# %%
df.head()
# Out:
#                                            Book Name              Author  \
# 0  I Don't Love You Anymore: Moving On and Living...       Rithvik Singh
# 1  My First Library: Boxset of 10 Board Books for...  Wonder House Books
# 2                         Amma Diarylo Konni Pageelu         Ravi Mantri
# 3                                      Atomic Habits         James Clear
# 4                            The Psychology of Money       Morgan Housel
#
#                Rating Customers_Rated    Price
# 0  4.1 out of 5 stars               0  ₹216.00
# 1  4.5 out of 5 stars               0  ₹399.00
# 2  4.8 out of 5 stars               0  ₹200.00
# 3  4.6 out of 5 stars               0  ₹499.99
# 4  4.6 out of 5 stars               0  ₹247.00

# %%
df.shape
# Out:
# (60, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                             Book Name  \
# 0   I Don't Love You Anymore: Moving On and Living...
# 1   My First Library: Boxset of 10 Board Books for...
# 2                          Amma Diarylo Konni Pageelu
# 3                                       Atomic Habits
# 4                             The Psychology of Money
# 5      Ikigai: Japanese secret to long and happy life
# 6                            Dr. Manish Raj (MR. Sir)
# 7   Educart NEET 37 Years Physics, Chemistry and B...
# 8   Pocket Rocket English Formula Book By Prashant...
# 9   The Power of Your Subconscious Mind: Original ...
# 10  My First Book of Patterns Pencil Control: Patt...
# 11  Dopamine Detox : A Short Guide to Remove Distr...
# 12  Animals Tales From Panchtantra: Timeless Stori...
# 13  Coloring Books Box Set: Pack of 12 Copy Color ...
# 14            Shrimad Bhagwat Geeta Yatharoop (Hindi)
# 15  The Mountain Is You: Transforming Self-Sabotag...
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                             Book Name  \
# 0   I Don't Love You Anymore: Moving On and Living...
# 1   My First Library: Boxset of 10 Board Books for...
# 2                          Amma Diarylo Konni Pageelu
# 3                                       Atomic Habits
# 4                             The Psychology of Money
# 5      Ikigai: Japanese secret to long and happy life
# 6                            Dr. Manish Raj (MR. Sir)
# 7   Educart NEET 37 Years Physics, Chemistry and B...
# 8   Pocket Rocket English Formula Book By Prashant...
# 9   The Power of Your Subconscious Mind: Original ...
# 10  My First Book of Patterns Pencil Control: Patt...
# 11  Dopamine Detox : A Short Guide to Remove Distr...
# 12  Animals Tales From Panchtantra: Timeless Stori...
# 13  Coloring Books Box Set: Pack of 12 Copy Color ...
# 14            Shrimad Bhagwat Geeta Yatharoop (Hindi)
# 15  The Mountain Is You: Transforming Self-Sabotag...
# ...

# %%
print(df.isnull().sum())
# Out:
# Book Name          0
# Author             0
# Rating             0
# Customers_Rated    0
# Price              0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# Book Name          object
# Author             object
# Rating             object
# Customers_Rated    object
# Price              object
# dtype: object
